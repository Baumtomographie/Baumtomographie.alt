# %% [markdown]
# <a href="https://colab.research.google.com/github/Baumtomographie/Baumtomographie.alt/blob/master/Ply2W.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install plyfile
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from plyfile import PlyData, PlyElement

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
with open('/content/drive/My Drive/2Umf+17.078.ply', 'rb') as f:
  plydata = PlyData.read(f)

# %%
plydata.elements[0].data['x']
# Out:
# memmap([-3.338864 , -3.3857453, -5.653207 , ...,  8.154662 ,  8.039868 ,
#          8.263542 ], dtype=float32)

# %%
plydata['vertex']['x']
# Out:
# memmap([-3.338864 , -3.3857453, -5.653207 , ...,  8.154662 ,  8.039868 ,
#          8.263542 ], dtype=float32)

# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
plt.plot(plydata['vertex']['x'], plydata['vertex']['z'])

# %%
plydata['vertex']
# Out:
# PlyElement('vertex', (PlyProperty('x', 'float'), PlyProperty('y', 'float'), PlyProperty('z', 'float')), count=1258, comments=[])

# %%
Punkteliste = []

# %%
for Ecke in plydata['vertex']:
  Punkteliste.append((Ecke['x'], Ecke['z']))

# %%
Punkteliste
# Out:
# [(-3.338864, 16.089226),
#  (-3.3857453, 16.058447),
#  (-5.653207, 14.560362),
#  (-5.59512, 14.595384),
#  (-5.685757, 14.52891),
#  (-3.964131, 15.712725),
#  (-3.955237, 15.71781),
#  (-2.882223, 16.295542),
#  (-2.9524193, 16.27641),
#  (-2.8352182, 16.31475),
#  (-7.044677, 13.35816),
#  (-7.1054177, 13.315952),
#  (-6.93543, 13.4468),
#  (-6.905012, 13.460519),
#  (-5.282438, 14.904413),
#  (-5.27569, 14.909729),
#  (-3.753162, 15.8491745),
#  (-3.7738192, 15.833849),
#  (-5.937554, 14.395121),
#  (-5.9376984, 14.3950205),
#  (-5.4764905, 14.697214),
#  (-5.4722867, 14.702264),
#  (-5.4150524, 14.781156),
#  (-1.805963, 16.643074),
#  (-1.8841157, 16.62434),
#  (6.240082, 15.615025),
#  (6.39428, 15.562912),
#  (5.255985, 16.115759),
#  (5.198045, 16.14481),
#  (-1.1843585, 16.800667),
#  (-1.1449689, 16.810822),
#  (4.811484, 16.291916),
#  (4.687723, 16.348059),
#  (-1.4082022, 16.781292),
#  (-1.4468193, 16.776138),
#  (-1.3374662, 16.7881),
#  (4.1390777, 16.516218),
# ...

# %%
# !pip install sectionproperties
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 205.2/205.2 KB 6.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 238.1/238.1 KB 16.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 41.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.4/9.4 MB 47.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 53.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.6/147.6 KB 15.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 300.0/300.0 KB 24.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 965.4/965.4 KB 47.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.1/51.1 KB 4.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.2.2
#     Uninstalling matplotlib-3.2.2:
# ...
